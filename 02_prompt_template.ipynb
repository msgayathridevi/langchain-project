# %% [markdown]
# # String Prompt Template

# %%
from langchain_core.prompts import PromptTemplate
prompt_template = PromptTemplate.from_template("What is the capital of {country}?")
prompt = prompt_template.invoke({"country": "India"})

# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
import os

load_dotenv()

llm = ChatOpenAI(
    model="deepseek-ai/deepseek-v4-pro",
    temperature=0,
    api_key=os.getenv("DEEPSEEK_API_KEY_PRO"),
    base_url="https://integrate.api.nvidia.com/v1"
)

# %%
response = llm.invoke(prompt)
print(response.content)
# Out:
# The capital of India is New Delhi.

# %% [markdown]
# # Chat Prompt Template

# %%
from langchain_core.prompts import ChatPromptTemplate
chat_template = ChatPromptTemplate([
    ("system", "You are a helpful assistant."),
    ("user", "What is the capital of {country}?"),
    
])

prompt = chat_template.invoke({"country": "India"})
print(prompt)
# Out:
# messages=[SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of India?', additional_kwargs={}, response_metadata={})]

# %%
response = llm.invoke(prompt)
response.content
# Out:
# 'The capital of India is **New Delhi**.'

# %% [markdown]
# # Messages Placeholder template

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage

prompt_template = ChatPromptTemplate([
    ("system", "You are a helpful assistant."),
    MessagesPlaceholder("msg")
])

prompt = prompt_template.invoke({"msg": [HumanMessage(content="What is the capital of France?")]
})
llm.invoke(prompt).content
# Out:
# 'The capital of France is **Paris**.'

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage, AIMessage

prompt_template = ChatPromptTemplate([
    ("system", "You are a helpful assistant."),
    MessagesPlaceholder(variable_name ="msg")
])

# Define multiple messages
messages = [
    HumanMessage(content="Hello, can you help me with Python Coding?"),
    AIMessage(content="Of course! What do you need help with?"),
    HumanMessage(content="I am stuck on adding two numbers in Python."),
]

# Invoking the prompt with messages
output = prompt_template.invoke({"msg": messages})
print(output)
# Out:
# messages=[SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello, can you help me with Python Coding?', additional_kwargs={}, response_metadata={}), AIMessage(content='Of course! What do you need help with?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='I am stuck on adding two numbers in Python.', additional_kwargs={}, response_metadata={})]

# %%
llm.invoke(output).content
# Out:
# 'No problem! Adding two numbers in Python is very straightforward. Here\'s the simplest way:\n\n```python\n# Basic addition\na = 5\nb = 3\nresult = a + b\nprint(result)  # Output: 8\n```\n\nIf you want to get input from the user:\n\n```python\n# Getting input from user\nnum1 = float(input("Enter first number: "))\nnum2 = float(input("Enter second number: "))\nresult = num1 + num2\nprint(f"The sum is: {result}")\n```\n\nOr as a simple function:\n\n```python\ndef add_numbers(x, y):\n    return x + y\n\n# Example usage\nprint(add_numbers(10, 20))  # Output: 30\n```\n\nWhat specific part are you stuck on? Are you getting an error, or is there a particular scenario you\'re trying to handle?'
